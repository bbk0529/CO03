# %%
from CO03 import *

# %%
filelist = "CO03.txt"
df=CO03(filelist)

# %%
df
# Out:
#      partnr   qty                              description
# 0    668436   360              Seal            VABD-S6-1-C
# 1    676811    62             Cover plate     VABB-S4-2-WT
# 2   4803949     0             Cover plate     VABB-S4-2-WT
# 3    678613  1784               S-head screw    M5X16-10.9
# 4    761657    86        Brief descript. VTSA/VTSAF-MP1-Z6
# 5    663010    86        Product label   BLANKO 51X20-1-GR
# 6    711989    86          Packaging label 102X126-26Z-L-G
# 7    307425   258    Ink ribbon      TTR 110X300M:SCHW:P-S
# 8    677519   258       Packaging label BLANKO 102X126-1-P
# 9    700304   230       Manif.sub-base  VABV-S4-2S-G18-2T2
# 10   668434   230           Sub-base        VABV-S4-2S-G18
# 11   699121   230       Flat module     E.VABV-S4-2S...2T2
# 12   700300   128       Manif.sub-base  VABV-S4-1S-G14-2T2
# 13   668449   128           Sub-base        VABV-S4-1S-G14
# 14   699119   128       Flat module     E.VABV-S4-1S...2T2
# ...

# %%
writer = pd.ExcelWriter('output2.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()
